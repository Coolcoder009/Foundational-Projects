# %% [markdown]
# ### **Data used - RAVDESS database(48kHz) & TESS database(22.5kHz)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install pydub
# !pip install noisereduce
# !pip install json_tricks

# %% [markdown]
# ##**Data Preprocessing**

# %% [markdown]
# *The audio samples are of different sample length, we have to make all the fles to be in same sample length, so let's find the maximum sample length in the audio samples and pad some audios whose sample length is less*

# %%
DATA_DIR = "/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/Data"

# %%
import os
import numpy as np
import librosa
import noisereduce as nr
from pydub import AudioSegment, effects
import tensorflow as tf
import keras
import sklearn
import matplotlib.pyplot as plt
from librosa import display

# %% [markdown]
# ##**Visualization & preprocessing on a single audio file**

# %%
audio = "/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/Data/Happy/OAF_back_happy.wav"

# %%
sound,sr= librosa.load(audio, sr=None) # audio is loaded as a np array
plt.figure(figsize=(10, 2))
librosa.display.waveshow(sound)

# %%
raw_sound = AudioSegment.from_file(audio)
normalizedsound = effects.normalize(raw_sound, headroom = 5.0) # Normalizing to 5DB (making the loudness to this threshold level)
normal_x = np.array(normalizedsound.get_array_of_samples(), dtype = 'float32')

plt.figure(figsize=(10,2))
librosa.display.waveshow(normal_x)

# %%
trim_audio, i = librosa.effects.trim(normal_x, top_db=30)
plt.figure(figsize=(10, 2))
librosa.display.waveshow(trim_audio)

# %%
# Function to find the max sample length
sample_lengths = []
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)
            audio, sr = librosa.load(file_path, sr=None)
            sample_lengths.append(len(audio))

print("Maximum Sample length is:",np.max(sample_lengths))
# Out:
# Maximum Sample length is: 145172

# %%
padded_x = np.pad(trim_audio, (0, 145172-len(trim_audio)), 'constant')
plt.figure(figsize=(10,2))
librosa.display.waveshow(padded_x)

# %%
final_x = nr.reduce_noise(y=padded_x,
                          sr = sr)
plt.figure(figsize=(10,2))
librosa.display.waveshow(final_x)

# %% [markdown]
# ##**Preprocessing on audio files**

# %%
total_length = 145172 # desired frame length for all of the audio samples.
frame_length = 2048
hop_length = 512

rms,zcr,mfccs= [], [], []
emotions = []

for root, dirs, files in os.walk(DATA_DIR):
  for file in files:
    if file.endswith(".wav"):
      file_path = os.path.join(root, file)

      emotion_label = os.path.basename(root).lower()
      emotions.append(emotion_label)
      audio, sr = librosa.load(file_path, sr=None) # load audio

      raw_sound = AudioSegment.from_file(file_path)

      normalizedsound = effects.normalize(raw_sound, headroom = 5.0) # normalize the audio

      normal_x = np.array(normalizedsound.get_array_of_samples(), dtype = 'float32')

      trim_audio, i = librosa.effects.trim(normal_x, top_db=30) # trim the audio where silence occurred

      padded_x = np.pad(trim_audio, (0, total_length-len(trim_audio)), 'constant') # pad the audio to maximum length

      final_x = nr.reduce_noise(y=padded_x,
                          sr = sr) # reduce noise if any

      # Features extraction
      f1 = librosa.feature.rms(y=final_x, frame_length=frame_length, hop_length=hop_length) # Energy - Root Mean Square

      f2 = librosa.feature.zero_crossing_rate(y=final_x , frame_length=frame_length, hop_length=hop_length, center=True) # ZCR

      f3 = librosa.feature.mfcc(y=final_x, sr=sr, n_mfcc=13, hop_length = hop_length) # MFCC

      rms.append(f1)
      zcr.append(f2)
      mfccs.append(f3)

# %%
f_rms = np.asarray(rms).astype('float32')
f_rms = np.swapaxes(f_rms,1,2)
f_zcr = np.asarray(zcr).astype('float32')
f_zcr = np.swapaxes(f_zcr,1,2)
f_mfccs = np.asarray(mfccs).astype('float32')
f_mfccs = np.swapaxes(f_mfccs,1,2)

# %%
print('ZCR shape:',f_zcr.shape)
print('RMS shape:',f_rms.shape)
print('MFCCs shape:',f_mfccs.shape)
# Out:
# ZCR shape: (2400, 284, 1)
# RMS shape: (2400, 284, 1)
# MFCCs shape: (2400, 284, 13)

# %%
# Concatenating all features to 'X' variable.
X = np.concatenate((f_zcr, f_rms, f_mfccs), axis=2)

from sklearn.preprocessing import LabelEncoder

# Convert string labels (e.g., 'happy', 'sad') to numeric
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(emotions)  # e.g., ['happy', 'sad'] → [0, 1]
print(Y)
Y = np.expand_dims(Y, axis=1)
print(Y)
# Out:
# [5 5 5 ... 0 0 0]
# [[5]
#  [5]
#  [5]
#  ...
#  [0]
#  [0]
#  [0]]

# %%
# Check label mapping
for i, label in enumerate(label_encoder.classes_):
    print(f"{label} → {i}")
# Out:
# angry → 0
# disgust → 1
# fear → 2
# happy → 3
# neutral → 4
# sad → 5

# %% [markdown]
# ##**Saving the data for later use as well**

# %%
import json

x_data = X.tolist()
x_path = '/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/X_datanew.json'
with open(x_path, 'w') as f:
    json.dump(x_data, f)

y_data = Y.tolist()
y_path = '/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/Y_datanew.json'
with open(y_path, 'w') as f:
    json.dump(y_data, f)

# %% [markdown]
# ##**Loading the saved data**

# %%
from json_tricks import dump, load
x_path = '/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/X_datanew.json'
X = load(x_path)
X = np.asarray(X, dtype = 'float32')

y_path = '/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/Y_datanew.json'
Y = load(y_path)
Y = np.asarray(Y, dtype = 'int8')

# %%
from sklearn.model_selection import train_test_split
x_train, x_tosplit, y_train, y_tosplit = train_test_split(X, Y, test_size = 0.125, random_state = 1)
x_val, x_test, y_val, y_test = train_test_split(x_tosplit, y_tosplit, test_size = 0.304, random_state = 1)

y_train_class = tf.keras.utils.to_categorical(y_train, 6)
y_val_class = tf.keras.utils.to_categorical(y_val, 6)

# %% [markdown]
# ##**Model Development**

# %%
from keras.models import Sequential
from keras import layers, optimizers, callbacks

# %%
model = Sequential()
model.add(layers.LSTM(64, return_sequences = True, input_shape = (X.shape[1:3])))
model.add(layers.LSTM(64))
model.add(layers.Dense(6,activation='softmax'))
print(model.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 284, 64)        │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,894 (210.52 KB)
#  Trainable params: 53,894 (210.52 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ##**Saving weights alone**

# %%
batch_size = 24
checkpoint_path = "/content/drive/MyDrive/Data/best_weights.weights.h5"
mcp_save = callbacks.ModelCheckpoint(
    checkpoint_path,
    save_best_only=True,
    save_weights_only=True,  # <== ADD THIS LINE
    monitor='val_categorical_accuracy',
    mode='max'
)

rlrop = callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',
                                    factor=0.1, patience=100)
# Compile & train
model.compile(loss='categorical_crossentropy',
                optimizer='RMSProp',
                metrics=['categorical_accuracy'])

history = model.fit(x_train, y_train_class,
                      epochs=200, batch_size = batch_size,
                      validation_data = (x_val, y_val_class),
                      callbacks = [mcp_save, rlrop])
# Define the best weights to the model.
model.load_weights(checkpoint_path)
# Out:
# Epoch 1/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 31s 295ms/step - categorical_accuracy: 0.1751 - loss: 1.7994 - val_categorical_accuracy: 0.2596 - val_loss: 1.7385 - learning_rate: 0.0010
# Epoch 2/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 289ms/step - categorical_accuracy: 0.2990 - loss: 1.6158 - val_categorical_accuracy: 0.3173 - val_loss: 1.5632 - learning_rate: 0.0010
# Epoch 3/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 298ms/step - categorical_accuracy: 0.3351 - loss: 1.5098 - val_categorical_accuracy: 0.3798 - val_loss: 1.3974 - learning_rate: 0.0010
# Epoch 4/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.4084 - loss: 1.3986 - val_categorical_accuracy: 0.4183 - val_loss: 1.3683 - learning_rate: 0.0010
# Epoch 5/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - categorical_accuracy: 0.3919 - loss: 1.3659 - val_categorical_accuracy: 0.4375 - val_loss: 1.2896 - learning_rate: 0.0010
# Epoch 6/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 24s 275ms/step - categorical_accuracy: 0.4254 - loss: 1.3294 - val_categorical_accuracy: 0.3990 - val_loss: 1.3589 - learning_rate: 0.0010
# Epoch 7/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - categorical_accuracy: 0.4214 - loss: 1.3017 - val_categorical_accuracy: 0.4327 - val_loss: 1.2612 - learning_rate: 0.0010
# Epoch 8/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.4287 - loss: 1.2641 - val_categorical_accuracy: 0.4712 - val_loss: 1.2312 - learning_rate: 0.0010
# Epoch 9/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - categorical_accuracy: 0.4423 - loss: 1.2593 - val_categorical_accuracy: 0.4856 - val_loss: 1.1559 - learning_rate: 0.0010
# Epoch 10/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.4631 - loss: 1.2519 - val_categorical_accuracy: 0.4952 - val_loss: 1.1394 - learning_rate: 0.0010
# Epoch 11/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.4782 - loss: 1.2204 - val_categorical_accuracy: 0.4038 - val_loss: 1.2387 - learning_rate: 0.0010
# Epoch 12/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 297ms/step - categorical_accuracy: 0.4617 - loss: 1.2314 - val_categorical_accuracy: 0.4856 - val_loss: 1.1809 - learning_rate: 0.0010
# Epoch 13/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 45s 343ms/step - categorical_accuracy: 0.4820 - loss: 1.1998 - val_categorical_accuracy: 0.5000 - val_loss: 1.1662 - learning_rate: 0.0010
# Epoch 14/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 35s 276ms/step - categorical_accuracy: 0.4679 - loss: 1.2066 - val_categorical_accuracy: 0.4760 - val_loss: 1.2559 - learning_rate: 0.0010
# Epoch 15/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 286ms/step - categorical_accuracy: 0.5000 - loss: 1.1466 - val_categorical_accuracy: 0.4712 - val_loss: 1.1214 - learning_rate: 0.0010
# Epoch 16/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 280ms/step - categorical_accuracy: 0.4739 - loss: 1.1811 - val_categorical_accuracy: 0.4231 - val_loss: 1.2473 - learning_rate: 0.0010
# Epoch 17/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - categorical_accuracy: 0.5039 - loss: 1.1606 - val_categorical_accuracy: 0.4423 - val_loss: 1.2902 - learning_rate: 0.0010
# Epoch 18/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 303ms/step - categorical_accuracy: 0.4953 - loss: 1.1819 - val_categorical_accuracy: 0.5144 - val_loss: 1.1749 - learning_rate: 0.0010
# Epoch 19/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 298ms/step - categorical_accuracy: 0.4998 - loss: 1.1281 - val_categorical_accuracy: 0.4856 - val_loss: 1.1111 - learning_rate: 0.0010
# Epoch 20/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 305ms/step - categorical_accuracy: 0.5199 - loss: 1.1120 - val_categorical_accuracy: 0.4808 - val_loss: 1.1021 - learning_rate: 0.0010
# Epoch 21/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 313ms/step - categorical_accuracy: 0.5430 - loss: 1.0952 - val_categorical_accuracy: 0.4808 - val_loss: 1.2211 - learning_rate: 0.0010
# Epoch 22/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 300ms/step - categorical_accuracy: 0.5308 - loss: 1.1071 - val_categorical_accuracy: 0.5385 - val_loss: 1.0294 - learning_rate: 0.0010
# Epoch 23/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 279ms/step - categorical_accuracy: 0.5347 - loss: 1.0964 - val_categorical_accuracy: 0.4279 - val_loss: 1.2567 - learning_rate: 0.0010
# Epoch 24/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 284ms/step - categorical_accuracy: 0.5414 - loss: 1.0898 - val_categorical_accuracy: 0.5144 - val_loss: 1.1717 - learning_rate: 0.0010
# Epoch 25/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 298ms/step - categorical_accuracy: 0.5678 - loss: 1.0610 - val_categorical_accuracy: 0.5433 - val_loss: 1.0805 - learning_rate: 0.0010
# Epoch 26/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 279ms/step - categorical_accuracy: 0.5584 - loss: 1.0596 - val_categorical_accuracy: 0.4519 - val_loss: 1.2112 - learning_rate: 0.0010
# Epoch 27/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 295ms/step - categorical_accuracy: 0.5752 - loss: 1.0393 - val_categorical_accuracy: 0.6202 - val_loss: 1.0276 - learning_rate: 0.0010
# Epoch 28/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 286ms/step - categorical_accuracy: 0.5703 - loss: 1.0229 - val_categorical_accuracy: 0.5817 - val_loss: 1.0274 - learning_rate: 0.0010
# Epoch 29/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 287ms/step - categorical_accuracy: 0.5675 - loss: 1.0397 - val_categorical_accuracy: 0.4952 - val_loss: 1.0959 - learning_rate: 0.0010
# Epoch 30/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 308ms/step - categorical_accuracy: 0.5946 - loss: 0.9793 - val_categorical_accuracy: 0.5673 - val_loss: 1.0920 - learning_rate: 0.0010
# Epoch 31/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 39s 282ms/step - categorical_accuracy: 0.5860 - loss: 0.9773 - val_categorical_accuracy: 0.3942 - val_loss: 1.6140 - learning_rate: 0.0010
# Epoch 32/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 289ms/step - categorical_accuracy: 0.6099 - loss: 0.9763 - val_categorical_accuracy: 0.5577 - val_loss: 1.1438 - learning_rate: 0.0010
# Epoch 33/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 304ms/step - categorical_accuracy: 0.5906 - loss: 0.9756 - val_categorical_accuracy: 0.5625 - val_loss: 1.0771 - learning_rate: 0.0010
# Epoch 34/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 295ms/step - categorical_accuracy: 0.6021 - loss: 0.9565 - val_categorical_accuracy: 0.5529 - val_loss: 1.0953 - learning_rate: 0.0010
# Epoch 35/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 287ms/step - categorical_accuracy: 0.5990 - loss: 0.9828 - val_categorical_accuracy: 0.6346 - val_loss: 0.8910 - learning_rate: 0.0010
# Epoch 36/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 286ms/step - categorical_accuracy: 0.5727 - loss: 0.9738 - val_categorical_accuracy: 0.5769 - val_loss: 1.0057 - learning_rate: 0.0010
# Epoch 37/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 289ms/step - categorical_accuracy: 0.5938 - loss: 0.9608 - val_categorical_accuracy: 0.4712 - val_loss: 1.2944 - learning_rate: 0.0010
# Epoch 38/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 290ms/step - categorical_accuracy: 0.5964 - loss: 0.9403 - val_categorical_accuracy: 0.6298 - val_loss: 0.9211 - learning_rate: 0.0010
# Epoch 39/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 290ms/step - categorical_accuracy: 0.6143 - loss: 0.9162 - val_categorical_accuracy: 0.5288 - val_loss: 1.1371 - learning_rate: 0.0010
# Epoch 40/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 288ms/step - categorical_accuracy: 0.6239 - loss: 0.9429 - val_categorical_accuracy: 0.5913 - val_loss: 1.0030 - learning_rate: 0.0010
# Epoch 41/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 307ms/step - categorical_accuracy: 0.6320 - loss: 0.8747 - val_categorical_accuracy: 0.4567 - val_loss: 1.2323 - learning_rate: 0.0010
# Epoch 42/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 296ms/step - categorical_accuracy: 0.6248 - loss: 0.9396 - val_categorical_accuracy: 0.6010 - val_loss: 0.9902 - learning_rate: 0.0010
# Epoch 43/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.6609 - loss: 0.8721 - val_categorical_accuracy: 0.5865 - val_loss: 0.9442 - learning_rate: 0.0010
# Epoch 44/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 305ms/step - categorical_accuracy: 0.6119 - loss: 0.9493 - val_categorical_accuracy: 0.6587 - val_loss: 0.8724 - learning_rate: 0.0010
# Epoch 45/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - categorical_accuracy: 0.6400 - loss: 0.8741 - val_categorical_accuracy: 0.6587 - val_loss: 0.8874 - learning_rate: 0.0010
# Epoch 46/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - categorical_accuracy: 0.6636 - loss: 0.8414 - val_categorical_accuracy: 0.6010 - val_loss: 0.9599 - learning_rate: 0.0010
# Epoch 47/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 300ms/step - categorical_accuracy: 0.6512 - loss: 0.8821 - val_categorical_accuracy: 0.6827 - val_loss: 0.8349 - learning_rate: 0.0010
# Epoch 48/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 317ms/step - categorical_accuracy: 0.6653 - loss: 0.8158 - val_categorical_accuracy: 0.5048 - val_loss: 1.4457 - learning_rate: 0.0010
# Epoch 49/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 301ms/step - categorical_accuracy: 0.6573 - loss: 0.8645 - val_categorical_accuracy: 0.6442 - val_loss: 0.9125 - learning_rate: 0.0010
# Epoch 50/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 285ms/step - categorical_accuracy: 0.6342 - loss: 0.9037 - val_categorical_accuracy: 0.6058 - val_loss: 0.9486 - learning_rate: 0.0010
# Epoch 51/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 292ms/step - categorical_accuracy: 0.7067 - loss: 0.7909 - val_categorical_accuracy: 0.6827 - val_loss: 0.8434 - learning_rate: 0.0010
# Epoch 52/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - categorical_accuracy: 0.6918 - loss: 0.8106 - val_categorical_accuracy: 0.5865 - val_loss: 0.9597 - learning_rate: 0.0010
# Epoch 53/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 284ms/step - categorical_accuracy: 0.6746 - loss: 0.8275 - val_categorical_accuracy: 0.6923 - val_loss: 0.7978 - learning_rate: 0.0010
# Epoch 54/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 284ms/step - categorical_accuracy: 0.7015 - loss: 0.7752 - val_categorical_accuracy: 0.6971 - val_loss: 0.7832 - learning_rate: 0.0010
# Epoch 55/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 287ms/step - categorical_accuracy: 0.6924 - loss: 0.7733 - val_categorical_accuracy: 0.5721 - val_loss: 1.0908 - learning_rate: 0.0010
# Epoch 56/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 306ms/step - categorical_accuracy: 0.6781 - loss: 0.8088 - val_categorical_accuracy: 0.6442 - val_loss: 0.8519 - learning_rate: 0.0010
# Epoch 57/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 39s 279ms/step - categorical_accuracy: 0.6775 - loss: 0.7985 - val_categorical_accuracy: 0.6394 - val_loss: 0.8724 - learning_rate: 0.0010
# Epoch 58/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - categorical_accuracy: 0.7174 - loss: 0.7516 - val_categorical_accuracy: 0.5144 - val_loss: 1.5431 - learning_rate: 0.0010
# Epoch 59/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 306ms/step - categorical_accuracy: 0.6848 - loss: 0.8204 - val_categorical_accuracy: 0.7019 - val_loss: 0.8134 - learning_rate: 0.0010
# Epoch 60/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 290ms/step - categorical_accuracy: 0.7107 - loss: 0.7520 - val_categorical_accuracy: 0.4615 - val_loss: 1.5115 - learning_rate: 0.0010
# Epoch 61/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - categorical_accuracy: 0.6833 - loss: 0.8041 - val_categorical_accuracy: 0.5721 - val_loss: 1.0436 - learning_rate: 0.0010
# Epoch 62/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.6950 - loss: 0.7624 - val_categorical_accuracy: 0.6923 - val_loss: 0.7974 - learning_rate: 0.0010
# Epoch 63/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 300ms/step - categorical_accuracy: 0.7017 - loss: 0.7603 - val_categorical_accuracy: 0.7356 - val_loss: 0.6978 - learning_rate: 0.0010
# Epoch 64/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 292ms/step - categorical_accuracy: 0.7020 - loss: 0.7673 - val_categorical_accuracy: 0.5673 - val_loss: 1.1677 - learning_rate: 0.0010
# Epoch 65/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 296ms/step - categorical_accuracy: 0.7172 - loss: 0.7450 - val_categorical_accuracy: 0.7260 - val_loss: 0.6894 - learning_rate: 0.0010
# Epoch 66/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 294ms/step - categorical_accuracy: 0.7098 - loss: 0.7417 - val_categorical_accuracy: 0.6538 - val_loss: 0.9187 - learning_rate: 0.0010
# Epoch 67/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.7310 - loss: 0.7178 - val_categorical_accuracy: 0.6202 - val_loss: 1.0576 - learning_rate: 0.0010
# Epoch 68/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 305ms/step - categorical_accuracy: 0.7359 - loss: 0.7032 - val_categorical_accuracy: 0.5625 - val_loss: 1.0639 - learning_rate: 0.0010
# Epoch 69/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 283ms/step - categorical_accuracy: 0.7038 - loss: 0.7824 - val_categorical_accuracy: 0.6875 - val_loss: 0.7659 - learning_rate: 0.0010
# Epoch 70/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 314ms/step - categorical_accuracy: 0.7334 - loss: 0.7000 - val_categorical_accuracy: 0.6250 - val_loss: 0.9649 - learning_rate: 0.0010
# Epoch 71/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 38s 279ms/step - categorical_accuracy: 0.7104 - loss: 0.7428 - val_categorical_accuracy: 0.5625 - val_loss: 1.0616 - learning_rate: 0.0010
# Epoch 72/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 290ms/step - categorical_accuracy: 0.7586 - loss: 0.6745 - val_categorical_accuracy: 0.6683 - val_loss: 0.8867 - learning_rate: 0.0010
# Epoch 73/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 290ms/step - categorical_accuracy: 0.7382 - loss: 0.6973 - val_categorical_accuracy: 0.6587 - val_loss: 0.9736 - learning_rate: 0.0010
# Epoch 74/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 291ms/step - categorical_accuracy: 0.7445 - loss: 0.6600 - val_categorical_accuracy: 0.7740 - val_loss: 0.5937 - learning_rate: 0.0010
# Epoch 75/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - categorical_accuracy: 0.7898 - loss: 0.5770 - val_categorical_accuracy: 0.7740 - val_loss: 0.5988 - learning_rate: 0.0010
# Epoch 76/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 301ms/step - categorical_accuracy: 0.7913 - loss: 0.5961 - val_categorical_accuracy: 0.6202 - val_loss: 0.9873 - learning_rate: 0.0010
# Epoch 77/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 318ms/step - categorical_accuracy: 0.7744 - loss: 0.6280 - val_categorical_accuracy: 0.6490 - val_loss: 0.9223 - learning_rate: 0.0010
# Epoch 78/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 38s 287ms/step - categorical_accuracy: 0.7741 - loss: 0.5950 - val_categorical_accuracy: 0.5144 - val_loss: 1.3343 - learning_rate: 0.0010
# Epoch 79/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 308ms/step - categorical_accuracy: 0.7655 - loss: 0.6444 - val_categorical_accuracy: 0.7500 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 80/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 39s 287ms/step - categorical_accuracy: 0.7842 - loss: 0.6057 - val_categorical_accuracy: 0.5721 - val_loss: 1.2464 - learning_rate: 0.0010
# Epoch 81/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 291ms/step - categorical_accuracy: 0.7689 - loss: 0.6047 - val_categorical_accuracy: 0.7740 - val_loss: 0.5968 - learning_rate: 0.0010
# Epoch 82/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - categorical_accuracy: 0.7768 - loss: 0.5778 - val_categorical_accuracy: 0.7740 - val_loss: 0.6406 - learning_rate: 0.0010
# Epoch 83/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 323ms/step - categorical_accuracy: 0.7922 - loss: 0.5711 - val_categorical_accuracy: 0.7067 - val_loss: 0.8675 - learning_rate: 0.0010
# Epoch 84/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 38s 291ms/step - categorical_accuracy: 0.7832 - loss: 0.5793 - val_categorical_accuracy: 0.7933 - val_loss: 0.5476 - learning_rate: 0.0010
# Epoch 85/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 283ms/step - categorical_accuracy: 0.7800 - loss: 0.6292 - val_categorical_accuracy: 0.7740 - val_loss: 0.5769 - learning_rate: 0.0010
# Epoch 86/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 286ms/step - categorical_accuracy: 0.7874 - loss: 0.5533 - val_categorical_accuracy: 0.6923 - val_loss: 0.7635 - learning_rate: 0.0010
# Epoch 87/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 295ms/step - categorical_accuracy: 0.7761 - loss: 0.5718 - val_categorical_accuracy: 0.7644 - val_loss: 0.6008 - learning_rate: 0.0010
# Epoch 88/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - categorical_accuracy: 0.8157 - loss: 0.4973 - val_categorical_accuracy: 0.7692 - val_loss: 0.7054 - learning_rate: 0.0010
# Epoch 89/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - categorical_accuracy: 0.8119 - loss: 0.5186 - val_categorical_accuracy: 0.6923 - val_loss: 0.7163 - learning_rate: 0.0010
# Epoch 90/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - categorical_accuracy: 0.7721 - loss: 0.5642 - val_categorical_accuracy: 0.6538 - val_loss: 0.8191 - learning_rate: 0.0010
# Epoch 91/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 283ms/step - categorical_accuracy: 0.7807 - loss: 0.5881 - val_categorical_accuracy: 0.8221 - val_loss: 0.5239 - learning_rate: 0.0010
# Epoch 92/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 303ms/step - categorical_accuracy: 0.7885 - loss: 0.5977 - val_categorical_accuracy: 0.7019 - val_loss: 0.7861 - learning_rate: 0.0010
# Epoch 93/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 39s 282ms/step - categorical_accuracy: 0.8213 - loss: 0.5244 - val_categorical_accuracy: 0.7933 - val_loss: 0.5557 - learning_rate: 0.0010
# Epoch 94/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - categorical_accuracy: 0.8470 - loss: 0.4273 - val_categorical_accuracy: 0.7596 - val_loss: 0.6670 - learning_rate: 0.0010
# Epoch 95/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 296ms/step - categorical_accuracy: 0.8320 - loss: 0.4916 - val_categorical_accuracy: 0.8125 - val_loss: 0.5112 - learning_rate: 0.0010
# Epoch 96/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - categorical_accuracy: 0.8390 - loss: 0.4399 - val_categorical_accuracy: 0.8125 - val_loss: 0.4735 - learning_rate: 0.0010
# Epoch 97/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 321ms/step - categorical_accuracy: 0.8385 - loss: 0.4796 - val_categorical_accuracy: 0.8269 - val_loss: 0.4587 - learning_rate: 0.0010
# Epoch 98/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 306ms/step - categorical_accuracy: 0.8332 - loss: 0.4972 - val_categorical_accuracy: 0.8269 - val_loss: 0.5306 - learning_rate: 0.0010
# Epoch 99/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 296ms/step - categorical_accuracy: 0.8518 - loss: 0.4239 - val_categorical_accuracy: 0.8125 - val_loss: 0.4992 - learning_rate: 0.0010
# Epoch 100/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 305ms/step - categorical_accuracy: 0.8743 - loss: 0.3786 - val_categorical_accuracy: 0.8510 - val_loss: 0.5748 - learning_rate: 0.0010
# Epoch 101/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 283ms/step - categorical_accuracy: 0.8833 - loss: 0.3718 - val_categorical_accuracy: 0.8462 - val_loss: 0.4698 - learning_rate: 0.0010
# Epoch 102/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - categorical_accuracy: 0.8765 - loss: 0.3737 - val_categorical_accuracy: 0.8413 - val_loss: 0.4842 - learning_rate: 0.0010
# Epoch 103/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 288ms/step - categorical_accuracy: 0.8653 - loss: 0.3869 - val_categorical_accuracy: 0.8702 - val_loss: 0.3663 - learning_rate: 0.0010
# Epoch 104/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 296ms/step - categorical_accuracy: 0.8819 - loss: 0.3544 - val_categorical_accuracy: 0.8365 - val_loss: 0.4261 - learning_rate: 0.0010
# Epoch 105/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 309ms/step - categorical_accuracy: 0.8686 - loss: 0.4015 - val_categorical_accuracy: 0.5048 - val_loss: 1.4674 - learning_rate: 0.0010
# Epoch 106/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 295ms/step - categorical_accuracy: 0.8663 - loss: 0.4129 - val_categorical_accuracy: 0.8413 - val_loss: 0.3989 - learning_rate: 0.0010
# Epoch 107/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 296ms/step - categorical_accuracy: 0.8746 - loss: 0.3632 - val_categorical_accuracy: 0.7933 - val_loss: 0.4238 - learning_rate: 0.0010
# Epoch 108/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - categorical_accuracy: 0.8864 - loss: 0.3286 - val_categorical_accuracy: 0.8702 - val_loss: 0.4336 - learning_rate: 0.0010
# Epoch 109/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.8833 - loss: 0.3486 - val_categorical_accuracy: 0.8798 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 110/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 301ms/step - categorical_accuracy: 0.8806 - loss: 0.3424 - val_categorical_accuracy: 0.8942 - val_loss: 0.2983 - learning_rate: 0.0010
# Epoch 111/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.8696 - loss: 0.3572 - val_categorical_accuracy: 0.8894 - val_loss: 0.3011 - learning_rate: 0.0010
# Epoch 112/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 314ms/step - categorical_accuracy: 0.8909 - loss: 0.3115 - val_categorical_accuracy: 0.8077 - val_loss: 0.5162 - learning_rate: 0.0010
# Epoch 113/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 38s 285ms/step - categorical_accuracy: 0.8715 - loss: 0.3861 - val_categorical_accuracy: 0.8702 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 114/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 288ms/step - categorical_accuracy: 0.8885 - loss: 0.3291 - val_categorical_accuracy: 0.7981 - val_loss: 0.5780 - learning_rate: 0.0010
# Epoch 115/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 285ms/step - categorical_accuracy: 0.9058 - loss: 0.2976 - val_categorical_accuracy: 0.8654 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 116/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 298ms/step - categorical_accuracy: 0.8956 - loss: 0.3303 - val_categorical_accuracy: 0.7740 - val_loss: 0.6668 - learning_rate: 0.0010
# Epoch 117/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 297ms/step - categorical_accuracy: 0.8848 - loss: 0.3293 - val_categorical_accuracy: 0.8894 - val_loss: 0.4026 - learning_rate: 0.0010
# Epoch 118/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.9049 - loss: 0.2924 - val_categorical_accuracy: 0.9087 - val_loss: 0.2425 - learning_rate: 0.0010
# Epoch 119/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 324ms/step - categorical_accuracy: 0.9080 - loss: 0.2782 - val_categorical_accuracy: 0.9327 - val_loss: 0.2157 - learning_rate: 0.0010
# Epoch 120/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 38s 295ms/step - categorical_accuracy: 0.9139 - loss: 0.2508 - val_categorical_accuracy: 0.8894 - val_loss: 0.2918 - learning_rate: 0.0010
# Epoch 121/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 284ms/step - categorical_accuracy: 0.8978 - loss: 0.2791 - val_categorical_accuracy: 0.9231 - val_loss: 0.2661 - learning_rate: 0.0010
# Epoch 122/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 286ms/step - categorical_accuracy: 0.8890 - loss: 0.3582 - val_categorical_accuracy: 0.9087 - val_loss: 0.2596 - learning_rate: 0.0010
# Epoch 123/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 298ms/step - categorical_accuracy: 0.9064 - loss: 0.2763 - val_categorical_accuracy: 0.8702 - val_loss: 0.4550 - learning_rate: 0.0010
# Epoch 124/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - categorical_accuracy: 0.9097 - loss: 0.2967 - val_categorical_accuracy: 0.8750 - val_loss: 0.3767 - learning_rate: 0.0010
# Epoch 125/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - categorical_accuracy: 0.9097 - loss: 0.2683 - val_categorical_accuracy: 0.8798 - val_loss: 0.3271 - learning_rate: 0.0010
# Epoch 126/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 306ms/step - categorical_accuracy: 0.8976 - loss: 0.2898 - val_categorical_accuracy: 0.8798 - val_loss: 0.4296 - learning_rate: 0.0010
# Epoch 127/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 38s 278ms/step - categorical_accuracy: 0.9033 - loss: 0.3066 - val_categorical_accuracy: 0.9087 - val_loss: 0.2860 - learning_rate: 0.0010
# Epoch 128/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 287ms/step - categorical_accuracy: 0.9173 - loss: 0.2450 - val_categorical_accuracy: 0.8894 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 129/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - categorical_accuracy: 0.9194 - loss: 0.2500 - val_categorical_accuracy: 0.8798 - val_loss: 0.3306 - learning_rate: 0.0010
# Epoch 130/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - categorical_accuracy: 0.9121 - loss: 0.2718 - val_categorical_accuracy: 0.8269 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 131/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - categorical_accuracy: 0.9112 - loss: 0.2801 - val_categorical_accuracy: 0.8558 - val_loss: 0.4731 - learning_rate: 0.0010
# Epoch 132/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 290ms/step - categorical_accuracy: 0.9010 - loss: 0.2693 - val_categorical_accuracy: 0.8942 - val_loss: 0.2966 - learning_rate: 0.0010
# Epoch 133/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 311ms/step - categorical_accuracy: 0.8991 - loss: 0.2811 - val_categorical_accuracy: 0.8606 - val_loss: 0.4385 - learning_rate: 0.0010
# Epoch 134/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - categorical_accuracy: 0.9023 - loss: 0.2976 - val_categorical_accuracy: 0.7212 - val_loss: 0.9456 - learning_rate: 0.0010
# Epoch 135/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 286ms/step - categorical_accuracy: 0.9141 - loss: 0.3114 - val_categorical_accuracy: 0.9087 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 136/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 297ms/step - categorical_accuracy: 0.9294 - loss: 0.2277 - val_categorical_accuracy: 0.8846 - val_loss: 0.3505 - learning_rate: 0.0010
# Epoch 137/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.9147 - loss: 0.2579 - val_categorical_accuracy: 0.9087 - val_loss: 0.3582 - learning_rate: 0.0010
# Epoch 138/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - categorical_accuracy: 0.9154 - loss: 0.2723 - val_categorical_accuracy: 0.8750 - val_loss: 0.3875 - learning_rate: 0.0010
# Epoch 139/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 301ms/step - categorical_accuracy: 0.9319 - loss: 0.2176 - val_categorical_accuracy: 0.8894 - val_loss: 0.3841 - learning_rate: 0.0010
# Epoch 140/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - categorical_accuracy: 0.9169 - loss: 0.2432 - val_categorical_accuracy: 0.9183 - val_loss: 0.2725 - learning_rate: 0.0010
# Epoch 141/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - categorical_accuracy: 0.9240 - loss: 0.2223 - val_categorical_accuracy: 0.9135 - val_loss: 0.2886 - learning_rate: 0.0010
# Epoch 142/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - categorical_accuracy: 0.9249 - loss: 0.2285 - val_categorical_accuracy: 0.8173 - val_loss: 0.4523 - learning_rate: 0.0010
# Epoch 143/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - categorical_accuracy: 0.9233 - loss: 0.2294 - val_categorical_accuracy: 0.8942 - val_loss: 0.2621 - learning_rate: 0.0010
# Epoch 144/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 290ms/step - categorical_accuracy: 0.9329 - loss: 0.1982 - val_categorical_accuracy: 0.8413 - val_loss: 0.5064 - learning_rate: 0.0010
# Epoch 145/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 290ms/step - categorical_accuracy: 0.9121 - loss: 0.2412 - val_categorical_accuracy: 0.9135 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 146/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 297ms/step - categorical_accuracy: 0.9360 - loss: 0.1962 - val_categorical_accuracy: 0.8269 - val_loss: 0.4627 - learning_rate: 0.0010
# Epoch 147/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 321ms/step - categorical_accuracy: 0.9158 - loss: 0.2489 - val_categorical_accuracy: 0.9183 - val_loss: 0.2641 - learning_rate: 0.0010
# Epoch 148/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 284ms/step - categorical_accuracy: 0.9401 - loss: 0.2003 - val_categorical_accuracy: 0.8558 - val_loss: 0.4905 - learning_rate: 0.0010
# Epoch 149/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 298ms/step - categorical_accuracy: 0.9362 - loss: 0.2039 - val_categorical_accuracy: 0.9327 - val_loss: 0.1950 - learning_rate: 0.0010
# Epoch 150/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 282ms/step - categorical_accuracy: 0.9240 - loss: 0.2270 - val_categorical_accuracy: 0.8942 - val_loss: 0.2994 - learning_rate: 0.0010
# Epoch 151/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 300ms/step - categorical_accuracy: 0.9263 - loss: 0.2258 - val_categorical_accuracy: 0.9087 - val_loss: 0.2998 - learning_rate: 0.0010
# Epoch 152/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 299ms/step - categorical_accuracy: 0.9123 - loss: 0.2552 - val_categorical_accuracy: 0.9231 - val_loss: 0.2716 - learning_rate: 0.0010
# Epoch 153/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 298ms/step - categorical_accuracy: 0.9349 - loss: 0.1835 - val_categorical_accuracy: 0.8942 - val_loss: 0.3591 - learning_rate: 0.0010
# Epoch 154/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 287ms/step - categorical_accuracy: 0.9248 - loss: 0.2193 - val_categorical_accuracy: 0.9183 - val_loss: 0.2559 - learning_rate: 0.0010
# Epoch 155/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - categorical_accuracy: 0.9178 - loss: 0.2305 - val_categorical_accuracy: 0.9135 - val_loss: 0.3686 - learning_rate: 0.0010
# Epoch 156/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - categorical_accuracy: 0.9289 - loss: 0.2172 - val_categorical_accuracy: 0.9038 - val_loss: 0.2835 - learning_rate: 0.0010
# Epoch 157/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 306ms/step - categorical_accuracy: 0.9335 - loss: 0.2048 - val_categorical_accuracy: 0.9087 - val_loss: 0.2632 - learning_rate: 0.0010
# Epoch 158/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - categorical_accuracy: 0.9489 - loss: 0.1604 - val_categorical_accuracy: 0.8846 - val_loss: 0.3914 - learning_rate: 0.0010
# Epoch 159/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 306ms/step - categorical_accuracy: 0.9216 - loss: 0.2312 - val_categorical_accuracy: 0.9038 - val_loss: 0.3338 - learning_rate: 0.0010
# Epoch 160/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 302ms/step - categorical_accuracy: 0.9453 - loss: 0.1782 - val_categorical_accuracy: 0.8990 - val_loss: 0.2611 - learning_rate: 0.0010
# Epoch 161/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 306ms/step - categorical_accuracy: 0.9421 - loss: 0.1779 - val_categorical_accuracy: 0.8990 - val_loss: 0.2995 - learning_rate: 0.0010
# Epoch 162/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 326ms/step - categorical_accuracy: 0.9424 - loss: 0.1929 - val_categorical_accuracy: 0.9327 - val_loss: 0.2790 - learning_rate: 0.0010
# Epoch 163/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 39s 303ms/step - categorical_accuracy: 0.9332 - loss: 0.1999 - val_categorical_accuracy: 0.8894 - val_loss: 0.3639 - learning_rate: 0.0010
# Epoch 164/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - categorical_accuracy: 0.9385 - loss: 0.1754 - val_categorical_accuracy: 0.8894 - val_loss: 0.3527 - learning_rate: 0.0010
# Epoch 165/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 298ms/step - categorical_accuracy: 0.9352 - loss: 0.1967 - val_categorical_accuracy: 0.8173 - val_loss: 0.5606 - learning_rate: 0.0010
# Epoch 166/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 281ms/step - categorical_accuracy: 0.9263 - loss: 0.2099 - val_categorical_accuracy: 0.8942 - val_loss: 0.2977 - learning_rate: 0.0010
# Epoch 167/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 300ms/step - categorical_accuracy: 0.9486 - loss: 0.1635 - val_categorical_accuracy: 0.9231 - val_loss: 0.2827 - learning_rate: 0.0010
# Epoch 168/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.9431 - loss: 0.1790 - val_categorical_accuracy: 0.8702 - val_loss: 0.3946 - learning_rate: 0.0010
# Epoch 169/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 307ms/step - categorical_accuracy: 0.9426 - loss: 0.1638 - val_categorical_accuracy: 0.8990 - val_loss: 0.3481 - learning_rate: 0.0010
# Epoch 170/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 303ms/step - categorical_accuracy: 0.9461 - loss: 0.1554 - val_categorical_accuracy: 0.9183 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 171/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 304ms/step - categorical_accuracy: 0.9406 - loss: 0.1972 - val_categorical_accuracy: 0.9087 - val_loss: 0.2942 - learning_rate: 0.0010
# Epoch 172/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 307ms/step - categorical_accuracy: 0.9338 - loss: 0.2219 - val_categorical_accuracy: 0.8990 - val_loss: 0.3569 - learning_rate: 0.0010
# Epoch 173/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 291ms/step - categorical_accuracy: 0.9322 - loss: 0.1954 - val_categorical_accuracy: 0.8798 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 174/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - categorical_accuracy: 0.9439 - loss: 0.1693 - val_categorical_accuracy: 0.9279 - val_loss: 0.2722 - learning_rate: 0.0010
# Epoch 175/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 306ms/step - categorical_accuracy: 0.9475 - loss: 0.1665 - val_categorical_accuracy: 0.8990 - val_loss: 0.3419 - learning_rate: 0.0010
# Epoch 176/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 25s 279ms/step - categorical_accuracy: 0.9359 - loss: 0.1974 - val_categorical_accuracy: 0.9087 - val_loss: 0.3289 - learning_rate: 0.0010
# Epoch 177/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 296ms/step - categorical_accuracy: 0.9361 - loss: 0.1801 - val_categorical_accuracy: 0.8894 - val_loss: 0.3846 - learning_rate: 0.0010
# Epoch 178/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - categorical_accuracy: 0.9395 - loss: 0.1923 - val_categorical_accuracy: 0.8990 - val_loss: 0.3242 - learning_rate: 0.0010
# Epoch 179/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - categorical_accuracy: 0.9571 - loss: 0.1432 - val_categorical_accuracy: 0.9231 - val_loss: 0.2317 - learning_rate: 0.0010
# Epoch 180/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - categorical_accuracy: 0.9520 - loss: 0.1496 - val_categorical_accuracy: 0.8798 - val_loss: 0.3417 - learning_rate: 0.0010
# Epoch 181/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 318ms/step - categorical_accuracy: 0.9438 - loss: 0.1771 - val_categorical_accuracy: 0.8702 - val_loss: 0.3707 - learning_rate: 0.0010
# Epoch 182/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 28s 321ms/step - categorical_accuracy: 0.9437 - loss: 0.1928 - val_categorical_accuracy: 0.8942 - val_loss: 0.3466 - learning_rate: 0.0010
# Epoch 183/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 317ms/step - categorical_accuracy: 0.9536 - loss: 0.1558 - val_categorical_accuracy: 0.9087 - val_loss: 0.2848 - learning_rate: 0.0010
# Epoch 184/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 40s 303ms/step - categorical_accuracy: 0.9433 - loss: 0.1768 - val_categorical_accuracy: 0.9183 - val_loss: 0.2965 - learning_rate: 0.0010
# Epoch 185/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - categorical_accuracy: 0.9532 - loss: 0.1495 - val_categorical_accuracy: 0.8798 - val_loss: 0.4994 - learning_rate: 0.0010
# Epoch 186/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 307ms/step - categorical_accuracy: 0.9508 - loss: 0.1723 - val_categorical_accuracy: 0.9087 - val_loss: 0.2608 - learning_rate: 0.0010
# Epoch 187/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 305ms/step - categorical_accuracy: 0.9396 - loss: 0.1822 - val_categorical_accuracy: 0.9087 - val_loss: 0.2627 - learning_rate: 0.0010
# Epoch 188/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - categorical_accuracy: 0.9608 - loss: 0.1385 - val_categorical_accuracy: 0.8846 - val_loss: 0.3653 - learning_rate: 0.0010
# Epoch 189/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 300ms/step - categorical_accuracy: 0.9565 - loss: 0.1495 - val_categorical_accuracy: 0.8702 - val_loss: 0.4413 - learning_rate: 0.0010
# Epoch 190/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 26s 299ms/step - categorical_accuracy: 0.9621 - loss: 0.1274 - val_categorical_accuracy: 0.8990 - val_loss: 0.2935 - learning_rate: 0.0010
# Epoch 191/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - categorical_accuracy: 0.9524 - loss: 0.1396 - val_categorical_accuracy: 0.9135 - val_loss: 0.2955 - learning_rate: 0.0010
# Epoch 192/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 300ms/step - categorical_accuracy: 0.9521 - loss: 0.1542 - val_categorical_accuracy: 0.8990 - val_loss: 0.4312 - learning_rate: 0.0010
# Epoch 193/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - categorical_accuracy: 0.9350 - loss: 0.2213 - val_categorical_accuracy: 0.9231 - val_loss: 0.2750 - learning_rate: 0.0010
# Epoch 194/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 310ms/step - categorical_accuracy: 0.9602 - loss: 0.1363 - val_categorical_accuracy: 0.9327 - val_loss: 0.2514 - learning_rate: 0.0010
# Epoch 195/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 306ms/step - categorical_accuracy: 0.9485 - loss: 0.1412 - val_categorical_accuracy: 0.9327 - val_loss: 0.2657 - learning_rate: 0.0010
# Epoch 196/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 311ms/step - categorical_accuracy: 0.9451 - loss: 0.1533 - val_categorical_accuracy: 0.9375 - val_loss: 0.2775 - learning_rate: 0.0010
# Epoch 197/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 312ms/step - categorical_accuracy: 0.9601 - loss: 0.1320 - val_categorical_accuracy: 0.9087 - val_loss: 0.3308 - learning_rate: 0.0010
# Epoch 198/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 330ms/step - categorical_accuracy: 0.9541 - loss: 0.1411 - val_categorical_accuracy: 0.9087 - val_loss: 0.2890 - learning_rate: 0.0010
# Epoch 199/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - categorical_accuracy: 0.9510 - loss: 0.1571 - val_categorical_accuracy: 0.8846 - val_loss: 0.3407 - learning_rate: 0.0010
# Epoch 200/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - categorical_accuracy: 0.9508 - loss: 0.1459 - val_categorical_accuracy: 0.8606 - val_loss: 0.4495 - learning_rate: 0.0010

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

model = Sequential()
model.add(layers.LSTM(64, return_sequences=True, input_shape=(X.shape[1:3])))
model.add(layers.LSTM(64))
model.add(layers.Dense(6, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ##**Loading the weights into the model**

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='RMSProp',
              metrics=['categorical_accuracy'])

checkpoint_path = "/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/best_weights.weights.h5"
model.load_weights(checkpoint_path)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
y_test_class = tf.keras.utils.to_categorical(y_test, 6)

# %%
loss, accuracy = model.evaluate(x_test, y_test_class, verbose=1)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_accuracy: 0.8871 - loss: 0.2109
# Test Loss: 0.2142, Test Accuracy: 0.8913

# %%
# Save complete model
model.save('/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/emotion_model.keras')

# %%
np.save('/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/label_classes.npy', label_encoder.classes_)

# %%
from sklearn.metrics import classification_report
import numpy as np

# Make predictions (replace `model` and `x_test` with your actual model and test data)
y_probs = model.predict(x_test)
y_pred = np.argmax(y_probs, axis=1)  # predicted class indices
y_true = y_test.flatten()            # true class indices

# Load label encoder classes (if not already loaded)
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.classes_ = np.load('/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/label_classes.npy', allow_pickle=True)

# Classification report
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step
#               precision    recall  f1-score   support
#
#        angry       0.90      1.00      0.95         9
#      disgust       0.88      0.93      0.90        15
#         fear       0.72      1.00      0.84        13
#        happy       1.00      0.64      0.78        22
#      neutral       1.00      0.96      0.98        24
#          sad       0.82      1.00      0.90         9
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.92      0.89        92
# weighted avg       0.91      0.89      0.89        92

# %% [markdown]
# ##**Function to preprocess the test audio file**

# %%
label_encoder = LabelEncoder()
label_encoder.classes_ = np.load('/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/label_classes.npy', allow_pickle=True)

def preprocess_audio(file_path, total_length=145172, frame_length=2048, hop_length=512):
    # Load and normalize
    audio, sr = librosa.load(file_path, sr=None)
    raw_sound = AudioSegment.from_file(file_path)
    normalizedsound = effects.normalize(raw_sound, headroom=5.0)
    normal_x = np.array(normalizedsound.get_array_of_samples(), dtype='float32')

    # Trim silence and pad
    trim_audio, _ = librosa.effects.trim(normal_x, top_db=30)
    padded_x = np.pad(trim_audio, (0, max(0, total_length - len(trim_audio))), 'constant')

    # Noise reduction
    final_x = nr.reduce_noise(y=padded_x, sr=sr)

    # Feature extraction
    f_rms = librosa.feature.rms(y=final_x, frame_length=frame_length, hop_length=hop_length).T
    f_zcr = librosa.feature.zero_crossing_rate(y=final_x, frame_length=frame_length, hop_length=hop_length).T
    f_mfccs = librosa.feature.mfcc(y=final_x, sr=sr, n_mfcc=13, hop_length=hop_length).T

    features = np.concatenate((f_zcr, f_rms, f_mfccs), axis=1)
    return np.expand_dims(features, axis=0).astype('float32')

# %% [markdown]
# ##**Testing on a audio file**

# %%
# Load the full model
model = load_model('/content/drive/MyDrive/Foundational_Projects/Speech_Emotion_Recognition/emotion_model.keras')  ved that way

# Preprocess the audio
file_path = '/content/YAF_young_happy.wav'  # path to your test .wav
X_test = preprocess_audio(file_path)

# Predict
pred = model.predict(X_test)
predicted_class = np.argmax(pred, axis=1)[0]
predicted_emotion = label_encoder.inverse_transform([predicted_class])[0]

print(f"Predicted Emotion: {predicted_emotion}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# Predicted Emotion: happy
